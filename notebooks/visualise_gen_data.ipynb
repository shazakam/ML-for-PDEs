# %%
import torch
import sys
sys.path.append('..')
from utils.visualisation_utils import tensor_to_gif
data = torch.load('../data/inference_output/deep_onet_heat.pt')

# %%
data.shape
# Out:
# torch.Size([100, 1, 64, 64])

# %%
tensor_to_gif(data.squeeze(),"sim_deep_onet_heat.gif")

# %%
torch.load('../data/train_data/heat_equation_m64_h0_minmax_N800.pt')['X'].shape
# Out:
# torch.Size([800, 200, 64, 64])
