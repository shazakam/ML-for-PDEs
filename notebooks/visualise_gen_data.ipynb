# %%
import torch
import sys
sys.path.append('..')
from utils.visualisation_utils import tensor_to_gif
data = torch.load('../data/train_data/heat_equation_m64_h0_minmax_N800.pt')

# %%
tensor_to_gif(data['X'][0])

# %%
data['X'][0].shape
# Out:
# torch.Size([200, 64, 64])
